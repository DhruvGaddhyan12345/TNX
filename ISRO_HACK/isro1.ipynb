# %% [markdown]
# 24th June

# %% [markdown]
# Mini Project 1
#
# Create embeddings manually.
#
# river = np.array([1,2,3])
#
# forest = np.array([2,4,6])
#
# city = np.array([10,10,10])

# %%
import numpy as np

# %%
river = np.array([1,2,3])

forest = np.array([2,4,6])

city = np.array([10,10,10])

print(np.dot(river,forest))
# Out:
# 28

# %% [markdown]
# Functions
# Classes***
# Lists
# Loops**
# NumPy Arrays
# Shapes**
# Vector Addition
# Dot Product
# Matrix Multiplication
# Broadcasting***
# Pandas DataFrame
# CSV Reading
# Matplotlib Plotting

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]

y = [2,4,6,8]

plt.plot(x,y)

plt.plot(x)
plt.show()

# %% [markdown]
# when we work in multiple data point it can get confused so it get confused so it is comulsary to show

# %%
plt.imshow(image)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.imshow(image)
#       2
#       3 plt.show()
#
# NameError: name 'image' is not defined

# %% [markdown]
# DATA- DATA IS COLLECTION OF INFORMATION..IN OUR PAT INFO CAN BE TEXT, SOUND, IMAGE, VIDEO--MULTIMODAL DATA
#
#
# Obtaining Data...PANDAS
# Understanding Data
# Cleaning Data....DUPLICATE DATA, VALUE MISSING(ELIMIATE OR SUBSTITURE-MEAN,MEDIAN,MODEL)
# Transforming Data...
# Preparing Data..
# Loading Data...
#
# Obtaining Data
# Understanding Data
# Cleaning Data
# Transforming Data
# Preparing Data
# Loading Data
#
#
# Raw Data
#     ↓
# Useful Data
#     ↓
# Model
#
#
# Satellite Images
# +
# Labels

# %% [markdown]
# PART 2: Types of Data
# Structured Data
#
# Tables.
#
#
# Semi-Structured Data
#
# JSON.
#
#
# Unstructured Data
#
# Most important for PS-11.
#
# Examples:
#
# Images
# Audio
# Video
# Text

# %% [markdown]
# PART 3: Loading Data
# PART 3: Loading Data
#
# import pandas as pd
#
# df = pd.read_csv("crop.csv")
# import pandas as pd
#
# df = pd.read_csv("crop.csv")
# df.head()##MUST DO
#
# df.head()
# df.head()df.shape

# %% [markdown]
# PART 4: Understanding Columns  df.columns   ***FEATURES

# %%
PART 5: Missing Values

Very common.

Example:

Temp	Rainfall
30	500
NaN	600

# %%
df.isnull().sum()......

1   0   3   4  IN CASE OF  REMOCE THE NA COLUMNS TAKE MEAN OF REST AND THEN FILL THAT

df.fillna(df.mean()) OR MEDIAN OR MODE

# %%
df.duplicated().sum()   df.drop_duplicates()**WE CAN KNOW IF DATA IS FAULTY IF LOT OF DUPLIACTE...OLD VIRUSES

# %%
import pandas as pd
df={"t":[30,],"r":[500,600]}

df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       1 import pandas as pd
#       2 df={"t":[30,],"r":[500,600]}
#       3
# ----> 4 df.describe()
#       5
#
# AttributeError: 'dict' object has no attribute 'describe'
